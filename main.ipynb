# %% [markdown]
# # Import Library

# %%
import os
import sys
from typing import Text

from absl import logging
from tfx.orchestration import metadata, pipeline
from tfx.orchestration.beam.beam_dag_runner import BeamDagRunner

# %% [markdown]
# # Set Variable

# %%
PIPELINE_NAME = 'loan-approval-pipeline'

DATA_ROOT = 'data'
TRANSFORM_MODULE_FILE = 'modules/loan_approval_transform.py'
TUNER_MODULE_FILE = 'modules/loan_approval_tuner.py'
TRAINER_MODULE_FILE = 'modules/loan_approval_trainer.py'

OUTPUT_BASE = 'output'
serving_model_dir = os.path.join(OUTPUT_BASE, 'serving_model')
pipeline_root = os.path.join(OUTPUT_BASE, PIPELINE_NAME)
metadata_path = os.path.join(pipeline_root, 'metadata.sqlite')

# %% [markdown]
# # Running pipeline

# %%
def init_local_pipeline(
    components, pipeline_root: Text
) -> pipeline.Pipeline:
    
    logging.info(f"Pipeline root set to: {pipeline_root}")
    beam_args = [
        "--direct_running_mode=multi_processing"
        # 0 auto-detect based on on the number of CPUs available 
        # during execution time.
        "----direct_num_workers=0" 
    ]
    
    return pipeline.Pipeline(
        pipeline_name=PIPELINE_NAME,
        pipeline_root=pipeline_root,
        components=components,
        enable_cache=True,
        metadata_connection_config=metadata.sqlite_metadata_connection_config(
            metadata_path
        ),
        eam_pipeline_args=beam_args
    )

if __name__ == "__main__":
    logging.set_verbosity(logging.INFO)
    
    from modules.components import init_components
    
    components = init_components(
        DATA_ROOT,
        training_module=TRAINER_MODULE_FILE,
        transform_module=TRANSFORM_MODULE_FILE,
        tuner_module=TUNER_MODULE_FILE,
        training_steps=5000,
        eval_steps=1000,
        serving_model_dir=serving_model_dir,
    )
    
    pipeline = init_local_pipeline(components, pipeline_root)
    BeamDagRunner().run(pipeline=pipeline)
# Out:
# Trial 10 Complete [00h 00m 15s]
# val_loss: 0.20676414668560028
#
# Best val_loss So Far: 0.20158222317695618
# Total elapsed time: 00h 01m 59s
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:absl:Finished tuning... Tuner ID: tuner0
# INFO:absl:Best HyperParameters: {'space': [{'class_name': 'Choice', 'config': {'name': 'num_hidden_layers', 'default': 1, 'conditions': [], 'values': [1, 2, 3], 'ordered': True}}, {'class_name': 'Int', 'config': {'name': 'dense_unit', 'default': None, 'conditions': [], 'min_value': 16, 'max_value': 256, 'step': 32, 'sampling': None}}, {'class_name': 'Float', 'config': {'name': 'dropout_rate', 'default': 0.1, 'conditions': [], 'min_value': 0.1, 'max_value': 0.9, 'step': 0.1, 'sampling': None}}, {'class_name': 'Choice', 'config': {'name': 'learning_rate', 'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}}], 'values': {'num_hidden_layers': 1, 'dense_unit': 240, 'dropout_rate': 0.5, 'learning_rate': 0.001, 'tuner/epochs': 5, 'tuner/initial_epoch': 2, 'tuner/bracket': 1, 'tuner/round': 1, 'tuner/trial_id': '0001'}}
# INFO:absl:Best Hyperparameters are written to output\loan-approval-pipeline\Tuner\best_hyperparameters\7\best_hyperparameters.txt.
# INFO:absl:Tuner results are written to output\loan-approval-pipeline\Tuner\tuner_results\7\tuner_results.json.
# INFO:absl:Cleaning up stateless execution info.
# INFO:absl:Execution 7 succeeded.
# INFO:absl:Cleaning up stateful execution info.
# INFO:absl:Publishing output artifacts defaultdict(<class 'list'>, {'best_hyperparameters': [Artifact(artifact: uri: "output\\loan-approval-pipeline\\Tuner\\best_hyperparameters\\7"
# , artifact_type: name: "HyperParameters"
# )], 'tuner_results': [Artifact(artifact: uri: "output\\loan-approval-pipeline\\Tuner\\tuner_results\\7"
# , artifact_type: name: "TunerResults"
# )]}) for execution 7
# INFO:absl:MetadataStore with DB connection initialized
# Results summary
# Results in output\loan-approval-pipeline\Tuner\.system\executor_execution\7\.temp\7\kt_hyperband
# Showing 10 best trials
# <keras_tuner.engine.objective.Objective object at 0x0000014759206040>
# Trial summary
# Hyperparameters:
# num_hidden_layers: 1
# dense_unit: 240
# dropout_rate: 0.5
# learning_rate: 0.001
# tuner/epochs: 5
# tuner/initial_epoch: 2
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 0001
# Score: 0.20158222317695618
# Trial summary
# Hyperparameters:
# num_hidden_layers: 3
# dense_unit: 16
# dropout_rate: 0.2
# learning_rate: 0.01
# tuner/epochs: 5
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.20676414668560028
# Trial summary
# Hyperparameters:
# num_hidden_layers: 3
# dense_unit: 240
# dropout_rate: 0.6
# learning_rate: 0.01
# tuner/epochs: 5
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.2075779289007187
# Trial summary
# Hyperparameters:
# num_hidden_layers: 3
# dense_unit: 16
# dropout_rate: 0.1
# learning_rate: 0.01
# tuner/epochs: 5
# tuner/initial_epoch: 2
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: 0003
# Score: 0.2173188328742981
# Trial summary
# Hyperparameters:
# num_hidden_layers: 3
# dense_unit: 16
# dropout_rate: 0.1
# learning_rate: 0.01
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.22053532302379608
# Trial summary
# Hyperparameters:
# num_hidden_layers: 1
# dense_unit: 240
# dropout_rate: 0.5
# learning_rate: 0.001
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.22304165363311768
# Trial summary
# Hyperparameters:
# num_hidden_layers: 2
# dense_unit: 48
# dropout_rate: 0.8
# learning_rate: 0.01
# tuner/epochs: 5
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.2409130483865738
# Trial summary
# Hyperparameters:
# num_hidden_layers: 1
# dense_unit: 144
# dropout_rate: 0.6
# learning_rate: 0.0001
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.26298192143440247
# Trial summary
# Hyperparameters:
# num_hidden_layers: 2
# dense_unit: 48
# dropout_rate: 0.1
# learning_rate: 0.0001
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.2769022285938263
# Trial summary
# Hyperparameters:
# num_hidden_layers: 3
# dense_unit: 48
# dropout_rate: 0.8
# learning_rate: 0.01
# tuner/epochs: 2
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.3387620449066162
# INFO:absl:node Tuner is finished.
# INFO:absl:node Trainer is running.
# INFO:absl:Running launcher for node_info {
#   type {
#     name: "tfx.components.trainer.component.Trainer"
#     base_type: TRAIN
#   }
#   id: "Trainer"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "loan-approval-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20250303-190325.532705"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "loan-approval-pipeline.Trainer"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "examples"
#     value {
#       channels {
#         producer_node_query {
#           id: "Transform"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "loan-approval-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20250303-190325.532705"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "loan-approval-pipeline.Transform"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Examples"
#             base_type: DATASET
#           }
#         }
#         output_key: "transformed_examples"
#       }
#       min_count: 1
#     }
#   }
#   inputs {
#     key: "hyperparameters"
#     value {
#       channels {
#         producer_node_query {
#           id: "Tuner"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "loan-approval-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20250303-190325.532705"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "loan-approval-pipeline.Tuner"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "HyperParameters"
#           }
#         }
#         output_key: "best_hyperparameters"
#       }
#     }
#   }
#   inputs {
#     key: "schema"
#     value {
#       channels {
#         producer_node_query {
#           id: "SchemaGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "loan-approval-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20250303-190325.532705"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "loan-approval-pipeline.SchemaGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Schema"
#           }
#         }
#         output_key: "schema"
#       }
#     }
#   }
#   inputs {
#     key: "transform_graph"
#     value {
#       channels {
#         producer_node_query {
#           id: "Transform"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "loan-approval-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20250303-190325.532705"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "loan-approval-pipeline.Transform"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "TransformGraph"
#           }
#         }
#         output_key: "transform_graph"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "model"
#     value {
#       artifact_spec {
#         type {
#           name: "Model"
#           base_type: MODEL
#         }
#       }
#     }
#   }
#   outputs {
#     key: "model_run"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelRun"
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "custom_config"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "eval_args"
#     value {
#       field_value {
#         string_value: "{\n  \"num_steps\": 1000,\n  \"splits\": [\n    \"eval\"\n  ]\n}"
#       }
#     }
#   }
#   parameters {
#     key: "module_path"
#     value {
#       field_value {
#         string_value: "loan_approval_trainer@output\\loan-approval-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+9392c197339da22998dafcd59f5eee30ec5d2408e97569dac214decef78be26e-py3-none-any.whl"
#       }
#     }
#   }
#   parameters {
#     key: "train_args"
#     value {
#       field_value {
#         string_value: "{\n  \"num_steps\": 5000,\n  \"splits\": [\n    \"train\"\n  ]\n}"
#       }
#     }
#   }
# }
# upstream_nodes: "SchemaGen"
# upstream_nodes: "Transform"
# upstream_nodes: "Tuner"
# downstream_nodes: "Evaluator"
# downstream_nodes: "Pusher"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
#
# INFO:absl:MetadataStore with DB connection initialized
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# INFO:absl:[Trainer] Resolved inputs: ({'examples': [Artifact(artifact: id: 8
# type_id: 15
# uri: "output\\loan-approval-pipeline\\Transform\\transformed_examples\\6"
# properties {
#   key: "split_names"
#   value {
#     string_value: "[\"eval\", \"train\"]"
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1741003510341
# last_update_time_since_epoch: 1741003510341
# , artifact_type: id: 15
# name: "Examples"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# properties {
#   key: "version"
#   value: INT
# }
# base_type: DATASET
# )], 'transform_graph': [Artifact(artifact: id: 9
# type_id: 25
# uri: "output\\loan-approval-pipeline\\Transform\\transform_graph\\6"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1741003510341
# last_update_time_since_epoch: 1741003510341
# , artifact_type: id: 25
# name: "TransformGraph"
# )], 'schema': [Artifact(artifact: id: 3
# type_id: 20
# uri: "output\\loan-approval-pipeline\\SchemaGen\\schema\\4"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1741003436583
# last_update_time_since_epoch: 1741003436583
# , artifact_type: id: 20
# name: "Schema"
# )], 'hyperparameters': [Artifact(artifact: id: 13
# type_id: 27
# uri: "output\\loan-approval-pipeline\\Tuner\\best_hyperparameters\\7"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1741003632958
# last_update_time_since_epoch: 1741003632958
# , artifact_type: id: 27
# name: "HyperParameters"
# )]},)
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:Going to run a new execution 8
# INFO:absl:Going to run a new execution: ExecutionInfo(execution_id=8, input_dict={'examples': [Artifact(artifact: id: 8
# type_id: 15
# uri: "output\\loan-approval-pipeline\\Transform\\transformed_examples\\6"
# properties {
#   key: "split_names"
#   value {
#     string_value: "[\"eval\", \"train\"]"
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1741003510341
# last_update_time_since_epoch: 1741003510341
# , artifact_type: id: 15
# name: "Examples"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# properties {
#   key: "version"
#   value: INT
# }
# base_type: DATASET
# )], 'transform_graph': [Artifact(artifact: id: 9
# type_id: 25
# uri: "output\\loan-approval-pipeline\\Transform\\transform_graph\\6"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1741003510341
# last_update_time_since_epoch: 1741003510341
# , artifact_type: id: 25
# name: "TransformGraph"
# )], 'schema': [Artifact(artifact: id: 3
# type_id: 20
# uri: "output\\loan-approval-pipeline\\SchemaGen\\schema\\4"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1741003436583
# last_update_time_since_epoch: 1741003436583
# , artifact_type: id: 20
# name: "Schema"
# )], 'hyperparameters': [Artifact(artifact: id: 13
# type_id: 27
# uri: "output\\loan-approval-pipeline\\Tuner\\best_hyperparameters\\7"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1741003632958
# last_update_time_since_epoch: 1741003632958
# , artifact_type: id: 27
# name: "HyperParameters"
# )]}, output_dict=defaultdict(<class 'list'>, {'model_run': [Artifact(artifact: uri: "output\\loan-approval-pipeline\\Trainer\\model_run\\8"
# , artifact_type: name: "ModelRun"
# )], 'model': [Artifact(artifact: uri: "output\\loan-approval-pipeline\\Trainer\\model\\8"
# , artifact_type: name: "Model"
# base_type: MODEL
# )]}), exec_properties={'custom_config': 'null', 'train_args': '{\n  "num_steps": 5000,\n  "splits": [\n    "train"\n  ]\n}', 'module_path': 'loan_approval_trainer@output\\loan-approval-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+9392c197339da22998dafcd59f5eee30ec5d2408e97569dac214decef78be26e-py3-none-any.whl', 'eval_args': '{\n  "num_steps": 1000,\n  "splits": [\n    "eval"\n  ]\n}'}, execution_output_uri='output\\loan-approval-pipeline\\Trainer\\.system\\executor_execution\\8\\executor_output.pb', stateful_working_dir='output\\loan-approval-pipeline\\Trainer\\.system\\stateful_working_dir\\20250303-190325.532705', tmp_dir='output\\loan-approval-pipeline\\Trainer\\.system\\executor_execution\\8\\.temp\\', pipeline_node=node_info {
#   type {
#     name: "tfx.components.trainer.component.Trainer"
#     base_type: TRAIN
#   }
#   id: "Trainer"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "loan-approval-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20250303-190325.532705"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "loan-approval-pipeline.Trainer"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "examples"
#     value {
#       channels {
#         producer_node_query {
#           id: "Transform"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "loan-approval-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20250303-190325.532705"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "loan-approval-pipeline.Transform"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Examples"
#             base_type: DATASET
#           }
#         }
#         output_key: "transformed_examples"
#       }
#       min_count: 1
#     }
#   }
#   inputs {
#     key: "hyperparameters"
#     value {
#       channels {
#         producer_node_query {
#           id: "Tuner"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "loan-approval-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20250303-190325.532705"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "loan-approval-pipeline.Tuner"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "HyperParameters"
#           }
#         }
#         output_key: "best_hyperparameters"
#       }
#     }
#   }
#   inputs {
#     key: "schema"
#     value {
#       channels {
#         producer_node_query {
#           id: "SchemaGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "loan-approval-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20250303-190325.532705"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "loan-approval-pipeline.SchemaGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Schema"
#           }
#         }
#         output_key: "schema"
#       }
#     }
#   }
#   inputs {
#     key: "transform_graph"
#     value {
#       channels {
#         producer_node_query {
#           id: "Transform"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "loan-approval-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20250303-190325.532705"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "loan-approval-pipeline.Transform"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "TransformGraph"
#           }
#         }
#         output_key: "transform_graph"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "model"
#     value {
#       artifact_spec {
#         type {
#           name: "Model"
#           base_type: MODEL
#         }
#       }
#     }
#   }
#   outputs {
#     key: "model_run"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelRun"
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "custom_config"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "eval_args"
#     value {
#       field_value {
#         string_value: "{\n  \"num_steps\": 1000,\n  \"splits\": [\n    \"eval\"\n  ]\n}"
#       }
#     }
#   }
#   parameters {
#     key: "module_path"
#     value {
#       field_value {
#         string_value: "loan_approval_trainer@output\\loan-approval-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+9392c197339da22998dafcd59f5eee30ec5d2408e97569dac214decef78be26e-py3-none-any.whl"
#       }
#     }
#   }
#   parameters {
#     key: "train_args"
#     value {
#       field_value {
#         string_value: "{\n  \"num_steps\": 5000,\n  \"splits\": [\n    \"train\"\n  ]\n}"
#       }
#     }
#   }
# }
# upstream_nodes: "SchemaGen"
# upstream_nodes: "Transform"
# upstream_nodes: "Tuner"
# downstream_nodes: "Evaluator"
# downstream_nodes: "Pusher"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
# , pipeline_info=id: "loan-approval-pipeline"
# , pipeline_run_id='20250303-190325.532705')
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# INFO:absl:udf_utils.get_fn {'custom_config': 'null', 'train_args': '{\n  "num_steps": 5000,\n  "splits": [\n    "train"\n  ]\n}', 'module_path': 'loan_approval_trainer@output\\loan-approval-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+9392c197339da22998dafcd59f5eee30ec5d2408e97569dac214decef78be26e-py3-none-any.whl', 'eval_args': '{\n  "num_steps": 1000,\n  "splits": [\n    "eval"\n  ]\n}'} 'run_fn'
# INFO:absl:Installing 'output\\loan-approval-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+9392c197339da22998dafcd59f5eee30ec5d2408e97569dac214decef78be26e-py3-none-any.whl' to a temporary directory.
# INFO:absl:Executing: ['c:\\Users\\Akbar\\anaconda3\\envs\\loan-approvement\\python.exe', '-m', 'pip', 'install', '--target', 'C:\\Users\\Akbar\\AppData\\Local\\Temp\\tmp7ues32me', 'output\\loan-approval-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+9392c197339da22998dafcd59f5eee30ec5d2408e97569dac214decef78be26e-py3-none-any.whl']
# INFO:absl:Successfully installed 'output\\loan-approval-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+9392c197339da22998dafcd59f5eee30ec5d2408e97569dac214decef78be26e-py3-none-any.whl'.
# INFO:absl:Training model.
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  person_gender_xf (InputLayer)  [(None, 3)]          0           []
#
#  person_education_xf (InputLaye  [(None, 6)]         0           []
#  r)
#
#  person_home_ownership_xf (Inpu  [(None, 5)]         0           []
#  tLayer)
#
#  loan_intent_xf (InputLayer)    [(None, 6)]          0           []
#
#  previous_loan_defaults_on_file  [(None, 3)]         0           []
#  _xf (InputLayer)
#
#  person_age_xf (InputLayer)     [(None, 1)]          0           []
#
#  person_income_xf (InputLayer)  [(None, 1)]          0           []
#
#  person_emp_exp_xf (InputLayer)  [(None, 1)]         0           []
#
#  loan_amnt_xf (InputLayer)      [(None, 1)]          0           []
#
#  loan_int_rate_xf (InputLayer)  [(None, 1)]          0           []
#
#  loan_percent_income_xf (InputL  [(None, 1)]         0           []
#  ayer)
#
#  cb_person_cred_hist_length_xf   [(None, 1)]         0           []
#  (InputLayer)
#
#  credit_score_xf (InputLayer)   [(None, 1)]          0           []
#
#  concatenate_1 (Concatenate)    (None, 31)           0           ['person_gender_xf[0][0]',
#                                                                   'person_education_xf[0][0]',
#                                                                   'person_home_ownership_xf[0][0]'
#                                                                  , 'loan_intent_xf[0][0]',
#                                                                   'previous_loan_defaults_on_file_
#                                                                  xf[0][0]',
#                                                                   'person_age_xf[0][0]',
#                                                                   'person_income_xf[0][0]',
#                                                                   'person_emp_exp_xf[0][0]',
#                                                                   'loan_amnt_xf[0][0]',
#                                                                   'loan_int_rate_xf[0][0]',
#                                                                   'loan_percent_income_xf[0][0]',
#                                                                   'cb_person_cred_hist_length_xf[0
#                                                                  ][0]',
#                                                                   'credit_score_xf[0][0]']
#
#  dense_5 (Dense)                (None, 240)          7680        ['concatenate_1[0][0]']
#
#  dense_6 (Dense)                (None, 240)          57840       ['dense_5[0][0]']
#
#  dropout_3 (Dropout)            (None, 240)          0           ['dense_6[0][0]']
#
#  dense_7 (Dense)                (None, 1)            241         ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 65,761
# Trainable params: 65,761
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/2
# 5000/5000 [==============================] - ETA: 0s - loss: 0.1994 - binary_accuracy: 0.9085
# Epoch 1: val_binary_accuracy improved from -inf to 0.91844, saving model to output\loan-approval-pipeline\Trainer\model\8\Format-Serving
# INFO:tensorflow:Assets written to: output\loan-approval-pipeline\Trainer\model\8\Format-Serving\assets
# INFO:tensorflow:Assets written to: output\loan-approval-pipeline\Trainer\model\8\Format-Serving\assets
# 5000/5000 [==============================] - 40s 8ms/step - loss: 0.1994 - binary_accuracy: 0.9085 - val_loss: 0.1893 - val_binary_accuracy: 0.9184
# Epoch 2/2
# 4996/5000 [============================>.] - ETA: 0s - loss: 0.1754 - binary_accuracy: 0.9208
# Epoch 2: val_binary_accuracy did not improve from 0.91844
# 5000/5000 [==============================] - 43s 9ms/step - loss: 0.1754 - binary_accuracy: 0.9208 - val_loss: 0.1917 - val_binary_accuracy: 0.9171
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:struct2tensor is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_decision_forests is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:tensorflow_text is not available.
# INFO:tensorflow:Assets written to: output\loan-approval-pipeline\Trainer\model\8\Format-Serving\assets
# INFO:tensorflow:Assets written to: output\loan-approval-pipeline\Trainer\model\8\Format-Serving\assets
# INFO:absl:Training complete. Model written to output\loan-approval-pipeline\Trainer\model\8\Format-Serving. ModelRun written to output\loan-approval-pipeline\Trainer\model_run\8
# INFO:absl:Cleaning up stateless execution info.
# INFO:absl:Execution 8 succeeded.
# INFO:absl:Cleaning up stateful execution info.
# INFO:absl:Publishing output artifacts defaultdict(<class 'list'>, {'model_run': [Artifact(artifact: uri: "output\\loan-approval-pipeline\\Trainer\\model_run\\8"
# , artifact_type: name: "ModelRun"
# )], 'model': [Artifact(artifact: uri: "output\\loan-approval-pipeline\\Trainer\\model\\8"
# , artifact_type: name: "Model"
# base_type: MODEL
# )]}) for execution 8
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:node Trainer is finished.
# INFO:absl:node Evaluator is running.
# INFO:absl:Running launcher for node_info {
#   type {
#     name: "tfx.components.evaluator.component.Evaluator"
#     base_type: EVALUATE
#   }
#   id: "Evaluator"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "loan-approval-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20250303-190325.532705"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "loan-approval-pipeline.Evaluator"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "baseline_model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Latest_blessed_model_resolver"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "loan-approval-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20250303-190325.532705"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "loan-approval-pipeline.Latest_blessed_model_resolver"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
#   inputs {
#     key: "examples"
#     value {
#       channels {
#         producer_node_query {
#           id: "CsvExampleGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "loan-approval-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20250303-190325.532705"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "loan-approval-pipeline.CsvExampleGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Examples"
#             base_type: DATASET
#           }
#         }
#         output_key: "examples"
#       }
#       min_count: 1
#     }
#   }
#   inputs {
#     key: "model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Trainer"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "loan-approval-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20250303-190325.532705"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "loan-approval-pipeline.Trainer"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "blessing"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelBlessing"
#         }
#       }
#     }
#   }
#   outputs {
#     key: "evaluation"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelEvaluation"
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "eval_config"
#     value {
#       field_value {
#         string_value: "{\n  \"metrics_specs\": [\n    {\n      \"metrics\": [\n        {\n          \"class_name\": \"MeanAbsoluteError\",\n          \"threshold\": {\n            \"value_threshold\": {\n              \"upper_bound\": 0.6\n            }\n          }\n        },\n        {\n          \"class_name\": \"MeanSquaredError\",\n          \"threshold\": {\n            \"value_threshold\": {\n              \"upper_bound\": 0.6\n            }\n          }\n        },\n        {\n          \"class_name\": \"RootMeanSquaredError\",\n          \"threshold\": {\n            \"value_threshold\": {\n              \"upper_bound\": 0.8\n            }\n          }\n        }\n      ]\n    }\n  ],\n  \"model_specs\": [\n    {\n      \"label_key\": \"loan_status\"\n    }\n  ],\n  \"slicing_specs\": [\n    {}\n  ]\n}"
#       }
#     }
#   }
#   parameters {
#     key: "example_splits"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "fairness_indicator_thresholds"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
# }
# upstream_nodes: "CsvExampleGen"
# upstream_nodes: "Latest_blessed_model_resolver"
# upstream_nodes: "Trainer"
# downstream_nodes: "Pusher"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
#
# INFO:absl:MetadataStore with DB connection initialized
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# INFO:absl:[Evaluator] Resolved inputs: ({'model': [Artifact(artifact: id: 16
# type_id: 31
# uri: "output\\loan-approval-pipeline\\Trainer\\model\\8"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1741003726127
# last_update_time_since_epoch: 1741003726127
# , artifact_type: id: 31
# name: "Model"
# base_type: MODEL
# )], 'baseline_model': [], 'examples': [Artifact(artifact: id: 1
# type_id: 15
# uri: "output\\loan-approval-pipeline\\CsvExampleGen\\examples\\1"
# properties {
#   key: "split_names"
#   value {
#     string_value: "[\"train\", \"eval\"]"
#   }
# }
# custom_properties {
#   key: "file_format"
#   value {
#     string_value: "tfrecords_gzip"
#   }
# }
# custom_properties {
#   key: "input_fingerprint"
#   value {
#     string_value: "split:single_split,num_files:1,total_bytes:3610978,xor_checksum:1740628749,sum_checksum:1740628749"
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "payload_format"
#   value {
#     string_value: "FORMAT_TF_EXAMPLE"
#   }
# }
# custom_properties {
#   key: "span"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1741003427175
# last_update_time_since_epoch: 1741003427175
# , artifact_type: id: 15
# name: "Examples"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# properties {
#   key: "version"
#   value: INT
# }
# base_type: DATASET
# )]},)
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:Going to run a new execution 9
# INFO:absl:Going to run a new execution: ExecutionInfo(execution_id=9, input_dict={'model': [Artifact(artifact: id: 16
# type_id: 31
# uri: "output\\loan-approval-pipeline\\Trainer\\model\\8"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1741003726127
# last_update_time_since_epoch: 1741003726127
# , artifact_type: id: 31
# name: "Model"
# base_type: MODEL
# )], 'baseline_model': [], 'examples': [Artifact(artifact: id: 1
# type_id: 15
# uri: "output\\loan-approval-pipeline\\CsvExampleGen\\examples\\1"
# properties {
#   key: "split_names"
#   value {
#     string_value: "[\"train\", \"eval\"]"
#   }
# }
# custom_properties {
#   key: "file_format"
#   value {
#     string_value: "tfrecords_gzip"
#   }
# }
# custom_properties {
#   key: "input_fingerprint"
#   value {
#     string_value: "split:single_split,num_files:1,total_bytes:3610978,xor_checksum:1740628749,sum_checksum:1740628749"
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "payload_format"
#   value {
#     string_value: "FORMAT_TF_EXAMPLE"
#   }
# }
# custom_properties {
#   key: "span"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1741003427175
# last_update_time_since_epoch: 1741003427175
# , artifact_type: id: 15
# name: "Examples"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# properties {
#   key: "version"
#   value: INT
# }
# base_type: DATASET
# )]}, output_dict=defaultdict(<class 'list'>, {'blessing': [Artifact(artifact: uri: "output\\loan-approval-pipeline\\Evaluator\\blessing\\9"
# , artifact_type: name: "ModelBlessing"
# )], 'evaluation': [Artifact(artifact: uri: "output\\loan-approval-pipeline\\Evaluator\\evaluation\\9"
# , artifact_type: name: "ModelEvaluation"
# )]}), exec_properties={'example_splits': 'null', 'eval_config': '{\n  "metrics_specs": [\n    {\n      "metrics": [\n        {\n          "class_name": "MeanAbsoluteError",\n          "threshold": {\n            "value_threshold": {\n              "upper_bound": 0.6\n            }\n          }\n        },\n        {\n          "class_name": "MeanSquaredError",\n          "threshold": {\n            "value_threshold": {\n              "upper_bound": 0.6\n            }\n          }\n        },\n        {\n          "class_name": "RootMeanSquaredError",\n          "threshold": {\n            "value_threshold": {\n              "upper_bound": 0.8\n            }\n          }\n        }\n      ]\n    }\n  ],\n  "model_specs": [\n    {\n      "label_key": "loan_status"\n    }\n  ],\n  "slicing_specs": [\n    {}\n  ]\n}', 'fairness_indicator_thresholds': 'null'}, execution_output_uri='output\\loan-approval-pipeline\\Evaluator\\.system\\executor_execution\\9\\executor_output.pb', stateful_working_dir='output\\loan-approval-pipeline\\Evaluator\\.system\\stateful_working_dir\\20250303-190325.532705', tmp_dir='output\\loan-approval-pipeline\\Evaluator\\.system\\executor_execution\\9\\.temp\\', pipeline_node=node_info {
#   type {
#     name: "tfx.components.evaluator.component.Evaluator"
#     base_type: EVALUATE
#   }
#   id: "Evaluator"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "loan-approval-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20250303-190325.532705"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "loan-approval-pipeline.Evaluator"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "baseline_model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Latest_blessed_model_resolver"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "loan-approval-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20250303-190325.532705"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "loan-approval-pipeline.Latest_blessed_model_resolver"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
#   inputs {
#     key: "examples"
#     value {
#       channels {
#         producer_node_query {
#           id: "CsvExampleGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "loan-approval-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20250303-190325.532705"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "loan-approval-pipeline.CsvExampleGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Examples"
#             base_type: DATASET
#           }
#         }
#         output_key: "examples"
#       }
#       min_count: 1
#     }
#   }
#   inputs {
#     key: "model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Trainer"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "loan-approval-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20250303-190325.532705"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "loan-approval-pipeline.Trainer"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "blessing"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelBlessing"
#         }
#       }
#     }
#   }
#   outputs {
#     key: "evaluation"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelEvaluation"
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "eval_config"
#     value {
#       field_value {
#         string_value: "{\n  \"metrics_specs\": [\n    {\n      \"metrics\": [\n        {\n          \"class_name\": \"MeanAbsoluteError\",\n          \"threshold\": {\n            \"value_threshold\": {\n              \"upper_bound\": 0.6\n            }\n          }\n        },\n        {\n          \"class_name\": \"MeanSquaredError\",\n          \"threshold\": {\n            \"value_threshold\": {\n              \"upper_bound\": 0.6\n            }\n          }\n        },\n        {\n          \"class_name\": \"RootMeanSquaredError\",\n          \"threshold\": {\n            \"value_threshold\": {\n              \"upper_bound\": 0.8\n            }\n          }\n        }\n      ]\n    }\n  ],\n  \"model_specs\": [\n    {\n      \"label_key\": \"loan_status\"\n    }\n  ],\n  \"slicing_specs\": [\n    {}\n  ]\n}"
#       }
#     }
#   }
#   parameters {
#     key: "example_splits"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "fairness_indicator_thresholds"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
# }
# upstream_nodes: "CsvExampleGen"
# upstream_nodes: "Latest_blessed_model_resolver"
# upstream_nodes: "Trainer"
# downstream_nodes: "Pusher"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
# , pipeline_info=id: "loan-approval-pipeline"
# , pipeline_run_id='20250303-190325.532705')
# ...
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x000001476C987100> and <keras.engine.input_layer.InputLayer object at 0x0000014771F925E0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x000001475D0CE4F0> and <keras.engine.input_layer.InputLayer object at 0x0000014759189880>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x000001475D0CE4F0> and <keras.engine.input_layer.InputLayer object at 0x0000014759189880>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x000001475A664610> and <keras.engine.input_layer.InputLayer object at 0x000001475A63F370>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x000001475A664610> and <keras.engine.input_layer.InputLayer object at 0x000001475A63F370>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x000001475C6A55B0> and <keras.engine.input_layer.InputLayer object at 0x000001476CA44220>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. For example, in the saved checkpoint object, `model.layer.weight` and `model.layer_copy.weight` reference the same variable, while in the current object these are two different variables. The referenced variables are:(<keras.saving.saved_model.load.TensorFlowTransform>TransformFeaturesLayer object at 0x000001475C6A55B0> and <keras.engine.input_layer.InputLayer object at 0x000001476CA44220>).
# INFO:absl:Evaluation complete. Results written to output\loan-approval-pipeline\Evaluator\evaluation\9.
# INFO:absl:Checking validation results.
# WARNING:tensorflow:From c:\Users\Akbar\anaconda3\envs\loan-approvement\lib\site-packages\tensorflow_model_analysis\writers\metrics_plots_and_validations_writer.py:110: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# WARNING:tensorflow:From c:\Users\Akbar\anaconda3\envs\loan-approvement\lib\site-packages\tensorflow_model_analysis\writers\metrics_plots_and_validations_writer.py:110: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# INFO:absl:Blessing result True written to output\loan-approval-pipeline\Evaluator\blessing\9.
# INFO:absl:Cleaning up stateless execution info.
# INFO:absl:Execution 9 succeeded.
# INFO:absl:Cleaning up stateful execution info.
# INFO:absl:Publishing output artifacts defaultdict(<class 'list'>, {'blessing': [Artifact(artifact: uri: "output\\loan-approval-pipeline\\Evaluator\\blessing\\9"
# , artifact_type: name: "ModelBlessing"
# )], 'evaluation': [Artifact(artifact: uri: "output\\loan-approval-pipeline\\Evaluator\\evaluation\\9"
# , artifact_type: name: "ModelEvaluation"
# )]}) for execution 9
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:node Evaluator is finished.
# INFO:absl:node Pusher is running.
# INFO:absl:Running launcher for node_info {
#   type {
#     name: "tfx.components.pusher.component.Pusher"
#     base_type: DEPLOY
#   }
#   id: "Pusher"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "loan-approval-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20250303-190325.532705"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "loan-approval-pipeline.Pusher"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Trainer"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "loan-approval-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20250303-190325.532705"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "loan-approval-pipeline.Trainer"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
#   inputs {
#     key: "model_blessing"
#     value {
#       channels {
#         producer_node_query {
#           id: "Evaluator"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "loan-approval-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20250303-190325.532705"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "loan-approval-pipeline.Evaluator"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "ModelBlessing"
#           }
#         }
#         output_key: "blessing"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "pushed_model"
#     value {
#       artifact_spec {
#         type {
#           name: "PushedModel"
#           base_type: MODEL
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "custom_config"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "push_destination"
#     value {
#       field_value {
#         string_value: "{\n  \"filesystem\": {\n    \"base_directory\": \"output\\\\serving_model\"\n  }\n}"
#       }
#     }
#   }
# }
# upstream_nodes: "Evaluator"
# upstream_nodes: "Trainer"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
#
# INFO:absl:MetadataStore with DB connection initialized
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# INFO:absl:[Pusher] Resolved inputs: ({'model': [Artifact(artifact: id: 16
# type_id: 31
# uri: "output\\loan-approval-pipeline\\Trainer\\model\\8"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1741003726127
# last_update_time_since_epoch: 1741003726127
# , artifact_type: id: 31
# name: "Model"
# base_type: MODEL
# )], 'model_blessing': [Artifact(artifact: id: 17
# type_id: 33
# uri: "output\\loan-approval-pipeline\\Evaluator\\blessing\\9"
# custom_properties {
#   key: "blessed"
#   value {
#     int_value: 1
#   }
# }
# custom_properties {
#   key: "current_model"
#   value {
#     string_value: "output\\loan-approval-pipeline\\Trainer\\model\\8"
#   }
# }
# custom_properties {
#   key: "current_model_id"
#   value {
#     int_value: 16
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1741003740674
# last_update_time_since_epoch: 1741003740674
# , artifact_type: id: 33
# name: "ModelBlessing"
# )]},)
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:Going to run a new execution 10
# INFO:absl:Going to run a new execution: ExecutionInfo(execution_id=10, input_dict={'model': [Artifact(artifact: id: 16
# type_id: 31
# uri: "output\\loan-approval-pipeline\\Trainer\\model\\8"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1741003726127
# last_update_time_since_epoch: 1741003726127
# , artifact_type: id: 31
# name: "Model"
# base_type: MODEL
# )], 'model_blessing': [Artifact(artifact: id: 17
# type_id: 33
# uri: "output\\loan-approval-pipeline\\Evaluator\\blessing\\9"
# custom_properties {
#   key: "blessed"
#   value {
#     int_value: 1
#   }
# }
# custom_properties {
#   key: "current_model"
#   value {
#     string_value: "output\\loan-approval-pipeline\\Trainer\\model\\8"
#   }
# }
# custom_properties {
#   key: "current_model_id"
#   value {
#     int_value: 16
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1741003740674
# last_update_time_since_epoch: 1741003740674
# , artifact_type: id: 33
# name: "ModelBlessing"
# )]}, output_dict=defaultdict(<class 'list'>, {'pushed_model': [Artifact(artifact: uri: "output\\loan-approval-pipeline\\Pusher\\pushed_model\\10"
# , artifact_type: name: "PushedModel"
# base_type: MODEL
# )]}), exec_properties={'custom_config': 'null', 'push_destination': '{\n  "filesystem": {\n    "base_directory": "output\\\\serving_model"\n  }\n}'}, execution_output_uri='output\\loan-approval-pipeline\\Pusher\\.system\\executor_execution\\10\\executor_output.pb', stateful_working_dir='output\\loan-approval-pipeline\\Pusher\\.system\\stateful_working_dir\\20250303-190325.532705', tmp_dir='output\\loan-approval-pipeline\\Pusher\\.system\\executor_execution\\10\\.temp\\', pipeline_node=node_info {
#   type {
#     name: "tfx.components.pusher.component.Pusher"
#     base_type: DEPLOY
#   }
#   id: "Pusher"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "loan-approval-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20250303-190325.532705"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "loan-approval-pipeline.Pusher"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "model"
#     value {
#       channels {
#         producer_node_query {
#           id: "Trainer"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "loan-approval-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20250303-190325.532705"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "loan-approval-pipeline.Trainer"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Model"
#             base_type: MODEL
#           }
#         }
#         output_key: "model"
#       }
#     }
#   }
#   inputs {
#     key: "model_blessing"
#     value {
#       channels {
#         producer_node_query {
#           id: "Evaluator"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "loan-approval-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20250303-190325.532705"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "loan-approval-pipeline.Evaluator"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "ModelBlessing"
#           }
#         }
#         output_key: "blessing"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "pushed_model"
#     value {
#       artifact_spec {
#         type {
#           name: "PushedModel"
#           base_type: MODEL
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "custom_config"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "push_destination"
#     value {
#       field_value {
#         string_value: "{\n  \"filesystem\": {\n    \"base_directory\": \"output\\\\serving_model\"\n  }\n}"
#       }
#     }
#   }
# }
# upstream_nodes: "Evaluator"
# upstream_nodes: "Trainer"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
# , pipeline_info=id: "loan-approval-pipeline"
# , pipeline_run_id='20250303-190325.532705')
# INFO:absl:Model version: 1741003741
# INFO:absl:Model written to serving path output\serving_model\1741003741.
# INFO:absl:Model pushed to output\loan-approval-pipeline\Pusher\pushed_model\10.
# INFO:absl:Cleaning up stateless execution info.
# INFO:absl:Execution 10 succeeded.
# INFO:absl:Cleaning up stateful execution info.
# INFO:absl:Publishing output artifacts defaultdict(<class 'list'>, {'pushed_model': [Artifact(artifact: uri: "output\\loan-approval-pipeline\\Pusher\\pushed_model\\10"
# , artifact_type: name: "PushedModel"
# base_type: MODEL
# )]}) for execution 10
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:node Pusher is finished.
